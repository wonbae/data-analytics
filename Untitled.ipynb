# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) 
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')



# %matplotlib inline


#Font
matplotlib.rc('font',family = 'NanumGothicCoding')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_dic = pd.read_csv("./data/wine_project/wine-data_dictionary.csv", encoding='949')
df_dic
# Out:
#                seq                        아이템의 순서
# 0           gender                         고객의 성별
# 1              age                     고객의 대략적 나이
# 2              job      직업(학생, 임시직, 자영업, 직장인, 전문직
# 3          marital                      고객의 결혼 상태
# 4         province                   고객의 주소(광역시도)
# 5             city                     고객의 주소(시구)
# 6          choice1                   첫 번째 선택한 포도주
# 7             side        시음회에 임의로 제공된 하나의 안주(치즈)
# 8          choice2  안주가 주어졌을 때 선택한 안주를 먹고 선택한 포도주
# 9              NaN                            NaN
# 10          prefer                 와인 선택시 주요 결정사항
# 11       frequency                           음주횟수
# 12  wine frequency                       와인 음주 횟수

# %%
df_area_province = pd.read_csv("./data/wine_project/wine_area_province.csv", encoding='949')
df_area_province
# Out:
#    Unnamed: 0                                  서울시  \
# 0           0  ['강남구', '양천구', '마포구', '강북구', '강동구']
#
#                                    부산시                                   경기도  \
# 0  ['사하구', '해운대구', '기장군', '연제구', '진구']  ['포천시', '화성시', '평택시', ' 가평군', '안양시']
#
#                                    충청도  \
# 0  ['청주시', '충주시', '천안시', '홍성군', '진천군']
#
#                                          경상도  \
# 0  ['함안군', '하동군', '포항시 남구', '포항시 북구', '거제시']
#
#                                    전라도
# 0  ['광양시', '해남군', '익산시', '곡성군', '구례군']

# %%
df_sales= pd.read_csv("./data/wine_project/wine_data_sales.csv")
df_sales.head(10)
# Out:
#    Unnamed: 0        date  gender     age     job  marital province city  \
# 0           0  2016-05-01  FEMALE     30대     임시직   SINGLE      충청도  청주시
# 1           1  2016-05-01  FEMALE     30대     변호사  MARREID      서울시  양천구
# 2           2  2016-05-01    MALE  60대 이상    회사직원   SINGLE      부산시  연제구
# 3           3  2016-05-01  FEMALE     40대  중소기업직원  MARREID      서울시  양천구
# 4           4  2016-05-01  FEMALE     50대      의사  MARREID      경상도  거제시
# 5           5  2016-05-01  FEMALE     20대     자영업  MARREID      서울시  양천구
# 6           6  2016-05-01    MALE     20대    벤처직원  MARREID      전라도  광양시
# 7           7  2016-05-01    MALE     40대      의사  MARREID      경상도  함안군
# 8           8  2016-05-01    MALE     30대      기자   SINGLE      서울시  강남구
# 9           9  2016-05-01    MALE     20대      학생  MARREID      경기도  가평군
#
#                purchase  amount
# 0  ['D', 'F', 'D', 'G']     100
# 1       ['C', 'G', 'E']      60
# 2            ['B', 'F']      30
# 3                 ['C']      15
# ...

# %%
df_quality_R= pd.read_csv("./data/wine_project/wine_quality_red.csv",encoding='949')
df_quality_R.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_quality_R.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_quality_W= pd.read_csv("./data/wine_project/wine_quality_white.csv",encoding='949')
df_quality_W.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_quality_W.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Side

# %%
df_side= pd.read_csv("./data/wine_project/wine_side.csv",encoding='949')
df_side.head(20)
# Out:
#     seq        side choice1
# 0     1       Annon       A
# 1     2   Roquefort       B
# 2     3     Cheddar       G
# 3     4  Gorgonzola       B
# 4     5  Gorgonzola       C
# 5     6   Camenbert       C
# 6     7       Annon       F
# 7     8       Annon       H
# 8     9        Brie       A
# 9    10    Valencay       B
# 10   11        Brie       E
# 11   12       Annon       E
# 12   13     Ricotta       E
# 13   14       Annon       E
# 14   15     Cheddar       D
# 15   16  Gorgonzola       E
# 16   17    Valencay       B
# 17   18     Cheddar       D
# 18   19  Gorgonzola       C
# 19   20     Ricotta       C

# %%
df_side.isnull().sum()
# Out:
# seq         0
# side       60
# choice1     0
# dtype: int64

# %%
df_side['choice1'].unique()
# Out:
# array(['A', 'B', 'G', 'C', 'F', 'H', 'E', 'D'], dtype=object)

# %%
df_preference['choice'].unique()
# Out:
# array(['A', 'D', 'B', 'C', 'G', 'H', 'E', 'F'], dtype=object)

# %%
df_side['side'].unique()
# Out:
# array(['Annon', 'Roquefort', 'Cheddar', 'Gorgonzola', 'Camenbert', 'Brie',
#        'Valencay', 'Ricotta', nan], dtype=object)

# %%
type(df_side['side'])
# Out:
# pandas.core.series.Series

# %%
df_side[df_side['side'].isnull()]
# Out:
#        seq side choice1
# 156    157  NaN       F
# 307    308  NaN       G
# 333    334  NaN       B
# 372    373  NaN       C
# 399    400  NaN       E
# 487    488  NaN       H
# 488    489  NaN       H
# 533    534  NaN       C
# 667    668  NaN       E
# 684    685  NaN       E
# 985    986  NaN       D
# 1005  1006  NaN       C
# 1149  1150  NaN       G
# 1168  1169  NaN       G
# 1217  1218  NaN       A
# 1544  1545  NaN       F
# 1709  1710  NaN       E
# 1916  1917  NaN       G
# 2143  2144  NaN       F
# 2407  2408  NaN       D
# 2550  2551  NaN       C
# 2615  2616  NaN       D
# 2825  2826  NaN       E
# 3055  3056  NaN       B
# 3846  3847  NaN       B
# 3852  3853  NaN       B
# 4003  4004  NaN       B
# 4351  4352  NaN       A
# 4400  4401  NaN       G
# 4560  4561  NaN       A
# 4578  4579  NaN       G
# 5195  5196  NaN       B
# 5224  5225  NaN       H
# 5380  5381  NaN       E
# 5502  5503  NaN       D
# 5507  5508  NaN       G
# 5618  5619  NaN       C
# ...

# %% [markdown]
# ## Frequency

# %%
df_frequency= pd.read_csv("./data/wine_project/wine_frequency.csv",encoding='949')
df_frequency.head(10)
# Out:
#    seq prefer  frequency  wineFrequency
# 0    1     당도          5              4
# 1    2    깊이감          2              1
# 2    3    깊이감          4              1
# 3    4     당도          1              1
# 4    5    깊이감          1              1
# 5    6    깊이감          3              2
# 6    7     당도          1              1
# 7    8    깊이감          3              2
# 8    9    깊이감          2              1
# 9   10     당도          1              1

# %%
df_sales.isnull().sum()
# Out:
# Unnamed: 0    0
# date          0
# gender        0
# age           0
# job           0
# marital       0
# province      0
# city          0
# purchase      0
# amount        0
# dtype: int64

# %% [markdown]
# ## Preference

# %%
df_preference = pd.read_csv("./data/wine_project/wine_data_preference.csv", encoding='949')
df_preference.head(10)
# Out:
#     seq  gender     age     job  marital province  city choice
# 0   1.0    MALE     50대  중소기업직원  MARREID      부산시  해운대구      A
# 1   2.0  FEMALE     30대     연구원   SINGLE      경상도   하동군      D
# 2   3.0  FEMALE     30대     자영업  MARREID      부산시   사하구      B
# 3   4.0  FEMALE     40대     자영업  MARREID      부산시   사하구      D
# 4   5.0  FEMALE     40대      의사  MARREID      서울시   강남구      C
# 5   6.0    MALE     50대    회사직원   SINGLE      부산시   사하구      G
# 6   7.0    MALE     30대     임시직  MARREID      서울시   강남구      H
# 7   8.0  FEMALE  60대 이상     임시직   SINGLE      서울시   강남구      C
# 8   9.0    MALE     20대      학생  MARREID      부산시  해운대구      D
# 9  10.0  FEMALE     50대     임시직  MARREID      경기도   포천시      D

# %%
df_preference.isnull().sum()
# Out:
# seq         17
# gender      10
# age          0
# job          0
# marital     30
# province    26
# city         0
# choice       0
# dtype: int64

# %%
df_side.columns
# Out:
# Index(['seq', 'side', 'choice1'], dtype='object')

# %% [markdown]
# ## Null에 대한 결측치

# %%
print(df_side.isnull().sum(),'\n++++++++++++++++++++\n')
print(df_preference.isnull().sum(),'\n++++++++++++++++++++\n')
print(df_quality_W.isnull().sum(),'\n++++++++++++++++++++\n')
print(df_quality_R.isnull().sum(),'\n++++++++++++++++++++\n')
print(df_area_province.isnull().sum(),'\n++++++++++++++++++++\n')
print(df_sales.isnull().sum(),'\n++++++++++++++++++++\n')
# Out:
# seq         0
# side       60
# choice1     0
# dtype: int64
# ++++++++++++++++++++
#
# seq         17
# gender      10
# age          0
# job          0
# marital     30
# province    26
# city         0
# choice       0
# dtype: int64
# ++++++++++++++++++++
#
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# ++++++++++++++++++++
#
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# ...

# %%
df_preference.isnull().sum()
# Out:
# seq         17
# gender      10
# age          0
# job          0
# marital     30
# province    26
# city         0
# choice       0
# dtype: int64

# %%
df_preference['gender'].unique()
# Out:
# array(['MALE', 'FEMALE', nan, 'UNKNOW'], dtype=object)

# %%
df_preference[df_preference['gender'].isnull() == True]['gender']
# Out:
# 176     NaN
# 196     NaN
# 3987    NaN
# 5466    NaN
# 5700    NaN
# 6628    NaN
# 7075    NaN
# 7449    NaN
# 8029    NaN
# 9991    NaN
# Name: gender, dtype: object

# %% [markdown]
# ## Quality_White

# %%
for col in df_quality_W:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_quality_W[df_quality_W[col] == 'UNKNOWN'])
    print(df_quality_W[df_quality_W[col] == 'UNKNOW'])
# Out:
# +++++++++++++++ fixed acidity +++++++++++++++
#
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
#
# +++++++++++++++ volatile acidity +++++++++++++++
#
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
#
# +++++++++++++++ citric acid +++++++++++++++
#
# Empty DataFrame
# ...

# %% [markdown]
# ## Quality_RED

# %%
for col in df_quality_R:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_quality_R[df_quality_R[col] == 'UNKNOWN'])
    print(df_quality_R[df_quality_R[col] == 'UNKNOW'])
# Out:
# +++++++++++++++ fixed acidity +++++++++++++++
#
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
#
# +++++++++++++++ volatile acidity +++++++++++++++
#
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []
#
# +++++++++++++++ citric acid +++++++++++++++
#
# Empty DataFrame
# ...

# %% [markdown]
# ## Area_province

# %%
for col in df_area_province:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_area_province[df_area_province[col] == 'UNKNOWN'])
    print(df_area_province[df_area_province[col] == 'UNKNOW'])
    print(df_area_province[df_area_province[col] == '미상'])
# Out:
# +++++++++++++++ Unnamed: 0 +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
#
# +++++++++++++++ 서울시 +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
#
# +++++++++++++++ 부산시 +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, 서울시, 부산시, 경기도, 충청도, 경상도, 전라도]
# Index: []
#
# +++++++++++++++ 경기도 +++++++++++++++
#
# Empty DataFrame
# ...

# %% [markdown]
# ## Frequency

# %%
# df_side
# df_preference
# df_frequency
# df_quality_W
# df_quality_R
# df_area_province
# df_sales

for col in df_frequency:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_frequency[df_frequency[col] == 'UNKNOWN'])
    print(df_frequency[df_frequency[col] == 'UNKNOW'])
    print(df_frequency[df_frequency[col] == '미상'])
# Out:
# +++++++++++++++ seq +++++++++++++++
#
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
#
# +++++++++++++++ prefer +++++++++++++++
#
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
#
# +++++++++++++++ frequency +++++++++++++++
#
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
#
# +++++++++++++++ wineFrequency +++++++++++++++
#
# Empty DataFrame
# Columns: [seq, prefer, frequency, wineFrequency]
# Index: []
# ...

# %% [markdown]
# ## Preperence

# %%
# df_side
# df_quality_W
# df_quality_R
# df_area_province
# df_sales
print(df_preference.isnull().sum())
for col in df_preference:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_preference[df_preference[col].isnull()])
#     print(df_preference[df_preference[col] == 'UNKNOWN'])
#     print(df_preference[df_preference[col] == 'UNKNOW'])
#     print(df_preference[df_preference[col] == '미상'])
# Out:
# seq         17
# gender      10
# age          0
# job          0
# marital     30
# province    26
# city         0
# choice       0
# dtype: int64
#
# +++++++++++++++ seq +++++++++++++++
#
#       seq  gender  age   job  marital province    city choice
# 289   NaN  FEMALE  40대    교수   SINGLE      부산시    해운대구      G
# 535   NaN  FEMALE  40대   자영업  MARREID      부산시     사하구      D
# 2324  NaN  FEMALE  50대  벤처직원   SINGLE      부산시    해운대구      D
# 3113  NaN  FEMALE  40대   자영업  MARREID      서울시     강남구      G
# 3151  NaN  FEMALE  40대   자영업  MARREID      부산시     연제구      D
# 3419  NaN    MALE  50대  벤처직원  MARREID      충청도     청주시      A
# 4731  NaN  FEMALE  40대   임시직   SINGLE      경상도  포항시 남구      A
# 4822  NaN    MALE  20대    학생   SINGLE      서울시     양천구      G
# 4884  NaN    MALE  30대    교수  MARREID      부산시      진구      E
# 5553  NaN    MALE  50대   임시직  MARREID      경기도     포천시      A
# 5845  NaN  FEMALE  50대    교수   SINGLE      서울시     강동구      C
# ...

# %%
print(df_preference['province'].unique())
print('\n')
print(df_preference['city'].unique())
# Out:
# ['부산시' '경상도' '서울시' '경기도' '충청도' '전라도' nan]
#
#
# ['해운대구' '하동군' '사하구' '강남구' '포천시' '거제시' '강북구' '청주시' '양천구' '해남군' '곡성군' '진구'
#  '함안군' '광양시' '안양시' '홍성군' '포항시 남구' '천안시' '기장군' '익산시' '평택시' '화성시' '마포구'
#  '강동구' '구례군' '포항시 북구' '연제구' '가평군' '진천군' '충주시']

# %%
for col in df_sales:
    print('\n+++++++++++++++',col,'+++++++++++++++\n')
    print(df_sales[df_sales[col] == 'UNKNOWN'])
    print(df_sales[df_sales[col] == 'UNKNOW'])
    print(df_sales[df_sales[col] == '미상'])
# Out:
# +++++++++++++++ Unnamed: 0 +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
#
# +++++++++++++++ date +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
#
# +++++++++++++++ gender +++++++++++++++
#
# Empty DataFrame
# Columns: [Unnamed: 0, date, gender, age, job, marital, province, city, purchase, amount]
# Index: []
# ...

# %% [markdown]
# ## Unkown에 대한 결측치

# %%
for x in df_side:
    print(df_side[x].unique())
# Out:
# [    1     2     3 ...  9998  9999 10000]
# ['Annon' 'Roquefort' 'Cheddar' 'Gorgonzola' 'Camenbert' 'Brie' 'Valencay'
#  'Ricotta' nan]
# ['A' 'B' 'G' 'C' 'F' 'H' 'E' 'D']

# %%
df_side.head()
# Out:
#    seq        side choice1
# 0    1       Annon       A
# 1    2   Roquefort       B
# 2    3     Cheddar       G
# 3    4  Gorgonzola       B
# 4    5  Gorgonzola       C

# %%
df_side.isnull().
# Out:
# seq         0
# side       60
# choice1     0
# dtype: int64

# %%
# print(df_side.isnull().sum())
res = []
for col in df_side:
    tmp = df_side[df_side[col]=='unkown']
    res.append(tmp)
res

# print(df_preference.isnull().sum(),'\n++++++++++++++++++++\n')
# print(df_quality_W.isnull().sum(),'\n++++++++++++++++++++\n')
# print(df_quality_R.isnull().sum(),'\n++++++++++++++++++++\n')
# print(df_area_province.isnull().sum(),'\n++++++++++++++++++++\n')
# print(df_sales.isnull().sum(),'\n++++++++++++++++++++\n')

# df_fitness = df_raw[df_raw["RSTPULSE"] < 100]
# df_fitness
# Out:
# [Empty DataFrame
#  Columns: [seq, side, choice1]
#  Index: [], Empty DataFrame
#  Columns: [seq, side, choice1]
#  Index: [], Empty DataFrame
#  Columns: [seq, side, choice1]
#  Index: []]

# %%
# df_side
# df_preference
# df_frequency
# df_quality_W
# df_quality_R
# df_area_province
# df_sales

# %%
df_sales.head()
df_preference.head()
# Out:
#    seq  gender  age     job  marital province  city choice
# 0  1.0    MALE  50대  중소기업직원  MARREID      부산시  해운대구      A
# 1  2.0  FEMALE  30대     연구원   SINGLE      경상도   하동군      D
# 2  3.0  FEMALE  30대     자영업  MARREID      부산시   사하구      B
# 3  4.0  FEMALE  40대     자영업  MARREID      부산시   사하구      D
# 4  5.0  FEMALE  40대      의사  MARREID      서울시   강남구      C

# %%
print(list(df_side.columns))
print('\n')
print(list(df_frequency.columns))
print('\n')
print(list(df_quality_W.columns))
print('\n')
print(list(df_quality_R.columns))
print('\n')
print(list(df_area_province.columns))
print('\n')
print(list(df_preference.columns))
print('\n')
print(list(df_sales.columns))
# Out:
# ['seq', 'side', 'choice1']
#
#
# ['seq', 'prefer', 'frequency', 'wineFrequency']
#
#
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
#
#
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
#
#
# ['Unnamed: 0', '서울시', '부산시', '경기도', '충청도', '경상도', '전라도']
#
#
# ['seq', 'gender', 'age', 'job', 'marital', 'province', 'city', 'choice']
#
#
# ['Unnamed: 0', 'date', 'gender', 'age', 'job', 'marital', 'province', 'city', 'purchase', 'amount']

# %%
df_new = pd.DataFrame()
df_new
df_preference['gender']
# Out:
# 9990

# %%
# df_preference
# df_sales['city'].isnull().sum()
df_preference['city'].isnull().sum()
# Out:
# 0

# %%
df_area_grade = pd.read_csv("./data/wine_project/wine_area_grade.csv", encoding='949')
df_area_grade.head(10)
# Out:
#   Unnamed: 0                                  Cities
# 0        1급지    ['강남구', '양천구', '기장군', '해운대구', '청주시']
# 1        2급지  ['포천시', '화성시', '포항시 남구', '강동구', '사하구']
# 2        3급지  ['강북구', '평택시', '가평군', '안양시', '포항시 북구']
# 3        4급지     ['광양시', '해남군', '연제구', '천안시', '마포구']
# 4        5급지      ['하동군', '함안군', '거제시', '진구', '홍성군']
# 5        6급지     ['충주시', '익산시', '구례군', '곡성군', '진천군']

# %%
df_quality_R.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_count = df_quality_R["quality"].value_counts()
df_count.plot.bar()

# %%
df_quality_R['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
# 'fixed acidity', 
# 'volatile acidity',
# 'citric acid',
# 'residual sugar',
# -------------------
# 'chlorides',
# 'free sulfur dioxide',
# 'total sulfur dioxide',
# 'density',
# 'pH',
# 'sulphates',
# 'alcohol',
# 'quality'

# 'A' = 35
# 'B' = 10
# 'C' = 15
# 'D' = 25
# 'E' = 15
# 'F' = 20
# 'G' = 30
# 'H' = 10

# A - G(30) - D - F(20) - (C, E(15)) - (B(10),H)

# %%
df_preference

# %%
df_count = df_preference["choice"].value_counts()
df_count.plot.bar()
